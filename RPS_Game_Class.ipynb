# %%
while True:
    chris = input("Chris to play, please type your selection >> rock, paper, scissors <<  ")
    player2 = input("player2 type your selection >> rock, paper, scissors <<  ")
    

    if chris == player2:
        print(f"same selection {player2}. It's a tie!")
    elif chris == "rock" and player2== "scissors":
          print("Rock beats scissors! Chris wins")
    elif chris == "scissors" and player2== "paper":
          print("scissors beats paper! Chris wins")        
    elif chris == "paper" and player2== "rock":
          print("paper beats rock! Chris wins")   
    elif player2 == "rock" and chris == "scissors":
          print("Rock beats scissors! player2 wins")
    elif player2 == "scissors" and chris == "paper":
          print("scissors beats paper! player2 wins")        
    elif player2 == "paper" and chris == "rock":
          print("paper beats rock! player2 wins")          
    play_again = input("Play again? (y/n): ")
    if play_again != "y":
        break
# Out:
# Chris to play, please type your selection >> rock, paper, scissors <<  rock
# player2 type your selection >> rock, paper, scissors <<  paper
# paper beats rock! player2 wins
# Play again? (y/n): y
# Chris to play, please type your selection >> rock, paper, scissors <<  paper
# player2 type your selection >> rock, paper, scissors <<  scissors
# scissors beats paper! player2 wins
# Play again? (y/n): n
